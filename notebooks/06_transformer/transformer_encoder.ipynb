# %% [markdown]
# # 06. Transformer Encoder
#
# **핵심 질문:** Multi-Head Attention, residual connection, LayerNorm, Feed Forward가 어떻게 하나의 encoder block을 이루는가?
#
# 작은 encoder layer를 직접 구현하고 각 단계의 tensor shape을 추적합니다.

# %%
import torch
import torch.nn as nn

x = torch.randn(2, 6, 32)  # [B,T,D]
print('input:', x.shape)

# %% [markdown]
# # 07-2. Tiny ViT — CIFAR-10
#
# **핵심 질문:** convolution 없이 patch token + self-attention으로 이미지를 분류할 수 있는가?
#
# 구성: Patch Embedding → CLS token → Positional Embedding → Transformer Encoder → MLP Head. 작은 모델로 직접 구현합니다.

# %%
import torch
import torch.nn as nn
from torchvision import datasets, transforms

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)

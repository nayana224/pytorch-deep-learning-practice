# %% [markdown]
# # 01. MLP — MNIST
#
# **핵심 질문:** 28×28 이미지를 784차원 vector로 펼쳤을 때 MLP는 무엇을 학습하고, 어떤 공간 정보를 잃는가?
#
# 진행: 데이터 확인 → MLP 구현 → 학습 → first-layer weight 시각화 → 결과 해석

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)

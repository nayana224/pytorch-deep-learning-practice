# %% [markdown]
# # 09-2. SAM 2 — Video Segmentation / Tracking
#
# **핵심 질문:** 한 프레임의 prompt가 memory를 통해 이후 프레임의 mask로 어떻게 전파되는가?
#
# 진행: video state 초기화 → 첫 프레임 point/box prompt → mask 확인 → `propagate_in_video` → frame별 결과 시각화.
#
# > GPU 사용을 권장합니다. 처음에는 짧은 영상과 작은 checkpoint로 시작하세요.

# %%
import torch
from pathlib import Path

VIDEO_DIR = Path('data/video_frames')
print('video dir:', VIDEO_DIR.resolve())
print('cuda:', torch.cuda.is_available())

# %% [markdown]
# # 09-1. SAM 2 — Image Inference
#
# **핵심 질문:** SAM 2의 image predictor는 SAM과 어떤 사용 흐름을 공유하고, 내부 architecture는 어떻게 달라지는가?
#
# 공식 SAM 2.1 checkpoint와 `SAM2ImagePredictor`를 사용합니다.
#
# > 실행 전 README의 SAM 2 별도 설치 절차를 확인하세요.

# %%
import torch
import matplotlib.pyplot as plt

print('torch:', torch.__version__)
print('cuda:', torch.cuda.is_available())

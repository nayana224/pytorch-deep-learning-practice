# %% [markdown]
# # 08-2. SAM — Custom Food 이미지 실험
#
# **핵심 질문:** 실제 음식 이미지에서 SAM mask는 현재 food mask 후보로 얼마나 쓸 수 있는가?
#
# 비교 항목: point prompt / box prompt / automatic mask, 음식 경계 누락, tray 포함 여부, 소스/국물/반사 영역.
#
# > 이 notebook은 실제 Custom Food 이미지를 넣어 비교 실험하는 자리입니다. 데이터 경로는 로컬 환경에 맞게 지정하세요.

# %%
from pathlib import Path
import torch
import matplotlib.pyplot as plt

DATA_DIR = Path('data/custom_food')
print('data dir:', DATA_DIR.resolve())

# %% [markdown]
# # 08-1. SAM — Image Inference
#
# **핵심 질문:** point/box prompt가 같은 이미지의 segmentation mask를 어떻게 바꾸는가?
#
# SAM은 처음부터 재구현하지 않습니다. 공식 pretrained 모델을 사용해 image encoder → prompt encoder → mask decoder 흐름을 관찰합니다.
#
# > 실행 전 README의 SAM 추가 설치 절차를 먼저 확인하세요.

# %%
import torch
import matplotlib.pyplot as plt

print('torch:', torch.__version__)
print('cuda:', torch.cuda.is_available())

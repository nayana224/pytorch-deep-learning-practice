# %% [markdown]
# # 02-2. CNN Filter / Feature Map 시각화
#
# **핵심 질문:** 학습 전후 filter weight와 feature map은 어떻게 달라지는가?
#
# 관찰 대상: conv1 filter, conv1 activation, conv2 activation, 동일 입력의 학습 전/후 비교

# %%
import torch
import matplotlib.pyplot as plt

print('torch:', torch.__version__)

# %% [markdown]
# # 05-1. Single-Head Attention
#
# **핵심 질문:** Q, K, V는 각각 어떤 역할을 하고 attention weight는 어떻게 만들어지는가?
#
# 작은 token tensor에서 `QK^T / sqrt(d_k) → softmax → V`를 직접 계산하고 attention matrix를 시각화합니다.

# %%
import math
import torch
import matplotlib.pyplot as plt

torch.manual_seed(0)
X = torch.randn(1, 4, 8)  # [B, T, D]
print(X.shape)

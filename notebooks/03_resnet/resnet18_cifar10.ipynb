# %% [markdown]
# # 03-2. ResNet-18 — CIFAR-10
#
# **핵심 질문:** residual connection을 쌓으면 plain CNN과 학습 안정성이 어떻게 달라지는가?
#
# 직접 만든 작은 ResNet과 `torchvision.models.resnet18` 구조를 비교합니다.

# %%
import torch
import torch.nn as nn
from torchvision import datasets, transforms, models

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)

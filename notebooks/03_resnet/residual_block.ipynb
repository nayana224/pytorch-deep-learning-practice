# %% [markdown]
# # 03-1. Residual Block
#
# **핵심 질문:** `F(x) + x`가 실제 forward/gradient 흐름을 어떻게 바꾸는가?
#
# 직접 `BasicBlock`을 구현하고 plain block과 비교합니다.

# %%
import torch
import torch.nn as nn

x = torch.randn(4, 16, 32, 32)
print(x.shape)

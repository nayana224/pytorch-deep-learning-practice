# %% [markdown]
# # 03-1. Residual Block
#
# 이 실습은 이제 `residual_block.py`에서 진행합니다.
#
# Notebook은 이전 cell 실행 상태가 남아 plain/residual 비교를 헷갈리게 만들 수 있으므로, 구조와 수치 검증은 Python 파일을 위에서 아래로 한 번에 실행합니다.
#
# 진행 파일: `notebooks/03_resnet/residual_block.py`
#
# 완성 코드는 미리 넣지 않았고, 단계별 TODO를 직접 타이핑하며 채우도록 구성했습니다.

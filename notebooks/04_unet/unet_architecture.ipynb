# %% [markdown]
# # 04-1. U-Net Architecture
#
# **핵심 질문:** encoder의 feature를 decoder에 skip connection으로 다시 전달하는 이유는 무엇인가?
#
# `DoubleConv`, `Down`, `Up`, `UNet`을 작은 형태로 직접 구현하며 shape을 추적합니다.

# %%
import torch
import torch.nn as nn

x = torch.randn(2, 1, 128, 128)
print('input:', x.shape)

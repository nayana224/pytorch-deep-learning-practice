# %% [markdown]
# # 04-2. U-Net Segmentation
#
# **핵심 질문:** image classification과 pixel-wise segmentation은 loss/output/평가 방식이 어떻게 다른가?
#
# 작은 segmentation 데이터셋으로 Input → Ground Truth → Prediction → Error Map을 비교하고 IoU/Dice를 계산합니다.

# %%
import torch
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)
